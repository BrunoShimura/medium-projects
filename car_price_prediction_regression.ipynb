# %%
# imports
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# plot all columns x price
for col in df.columns:
  sns.relplot(
      data=df,
      x=col, y="price"
  )
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:447: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize)

# %%
# Look at the proportion of missing data
df.isnull().mean()
# Out:
# car_ID              0.0
# symboling           0.0
# CarName             0.0
# fueltype            0.0
# aspiration          0.0
# doornumber          0.0
# carbody             0.0
# drivewheel          0.0
# enginelocation      0.0
# wheelbase           0.0
# carlength           0.0
# carwidth            0.0
# carheight           0.0
# curbweight          0.0
# enginetype          0.0
# cylindernumber      0.0
# enginesize          0.0
# fuelsystem          0.0
# boreratio           0.0
# stroke              0.0
# compressionratio    0.0
# horsepower          0.0
# peakrpm             0.0
# citympg             0.0
# highwaympg          0.0
# price               0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
# Defining a mapping dictionary
fueltype_mapping = {'gas': 1, 'diesel': 2}
enginelocation_mapping = {'front': 1, 'rear': 2}
fuelsystem_mapping = {'mpfi': 1,'2bbl': 2, 'mfi': 3, '1bbl': 4, 'spfi': 5, '4bbl': 6, 'idi': 7, 'spdi': 8}
aspirationtype_mapping = {'std': 1, 'turbo': 2}
carbody_mapping = {'convertible': 1, 'hatchback': 2, 'sedan': 3, 'wagon': 4, 'hardtop': 5}
drivewheel_mapping = {'rwd': 1, 'fwd': 2, '4wd': 3}
doornumber_mapping = {'two': 2, 'four': 4}
enginetype_mapping = {'dohc': 1, 'ohcv': 2, 'ohc': 3, 'l': 4, 'rotor': 5, 'ohcf': 6, 'dohcv': 7}
cylindernumber_mapping = {'four': 4, 'six': 6, 'five': 6, 'three': 3, 'twelve': 12, 'two': 2, 'eight': 8}

#Using the pat function to apply the mapping to all columns
df['fueltype'] = df['fueltype'].map(fueltype_mapping)
df['enginelocation'] = df['enginelocation'].map(enginelocation_mapping)
df['fuelsystem'] = df['fuelsystem'].map(fuelsystem_mapping)
df['aspiration'] = df['aspiration'].map(aspirationtype_mapping)
df['carbody'] = df['carbody'].map(carbody_mapping)
df['drivewheel'] = df['drivewheel'].map(drivewheel_mapping)
df['doornumber'] = df['doornumber'].map(doornumber_mapping)
df['enginetype'] = df['enginetype'].map(enginetype_mapping)
df['cylindernumber'] = df['cylindernumber'].map(cylindernumber_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    int64
#  4   aspiration        205 non-null    int64
#  5   doornumber        205 non-null    int64
#  6   carbody           205 non-null    int64
#  7   drivewheel        205 non-null    int64
#  8   enginelocation    205 non-null    int64
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    int64
#  15  cylindernumber    205 non-null    int64
# ...

# %%
df["enginelocation"].unique()
# Out:
# array([1, 2])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import numpy as np

# %%
X = df.drop(['CarName', 'price', 'symboling', 'fueltype', 'aspiration', 'carbody', 'enginelocation', 'enginetype', 'fuelsystem', 'stroke', 'compressionratio', 'peakrpm', 'carheight','doornumber'], axis='columns')
y = df['price']

# %%
print(X.shape, y.shape)
# Out:
# (205, 12) (205,)

# %%
# train 60%
X_train, X_, y_train, y_ = train_test_split(X, y, test_size=0.40, random_state=1)

# %%
# test 20% and validation 20%
X_cv, X_test, y_cv, y_test = train_test_split(X_, y_, test_size=0.50, random_state=1)

# %%
# Initialize the class
linear_model = LinearRegression()
# Train the model
linear_model.fit(X_train, y_train )
# Out:
# LinearRegression()

# %%
# Feed the scaled training set and get the predictions
yhat = linear_model.predict(X_train)
print(f"training MSE: {mean_absolute_error(y_train, yhat)}")
# Out:
# training MSE: 2330.3130808233163

# %%
# Feed the scaled cross validation set
yhatcv = linear_model.predict(X_cv)
# Use scikit-learn's utility function and divide by 2
print(f"Cross validation MSE: {mean_absolute_error(y_cv, yhatcv)}")
# Out:
# Cross validation MSE: 2436.459477314953

# %%
linear_model.score(X_train, y_train)
# Out:
# 0.8322940744564481

# %%
predict = linear_model.predict(X_test)

# %%
mean_absolute_error(predict, y_test)
# Out:
# 1998.5089493940368

# %%
import numpy as np
np.subtract(predict, y_test).mean()
# Out:
# 31.662168029133902

# %%
predict, y_test
# Out:
# array([17450. , 10345. ,  6095. ,  8845. ,  5118. ,  6695. ,  8238. ,
#         7609. , 18344. ,  7799. ,  9298. ,  7299. , 18150. ,  8558. ,
#        15750. ,  7995. ,  7775. ,  8921. , 11900. , 22625. ,  6338. ,
#         9295. , 17950. , 40960. , 11199. ,  9960. , 12764. , 11259. ,
#         7099. , 18950. , 19699. , 14489. ,  7349. , 10198. , 10898. ,
#        15645. ,  6855. ,  7395. ,  8916.5,  8845. , 11248. ])

# %%
nameCar = []
for i in y_test.index:
  nameCar.append(df.loc[i]['CarName'])

# %%
data1 = {
  "name": nameCar,
  "price": y_test.values,
  "prediction": predict
}

df1 = pd.DataFrame(data1)

# %%
df1
# Out:
#                          name    price    prediction
# 0                  audi 100ls  17450.0  14847.621124
# 1          honda civic (auto)  10345.0  11221.351523
# 2            maxda glc deluxe   6095.0   6524.796333
# 3                   mazda 626   8845.0  11512.174313
# 4                      subaru   5118.0   6389.802476
# 5                  mazda rx-4   6695.0   6502.889570
# 6               toyota corona   8238.0   8269.939552
# 7    plymouth fury gran sedan   7609.0   6495.253152
# 8               mazda rx-7 gs  18344.0  13367.548459
# 9                 nissan juke   7799.0   6465.451507
# 10  toyota celica gt liftback   9298.0  10387.729305
# 11                nissan leaf   7299.0   6264.188129
# 12              peugeot 604sl  18150.0  18471.080872
# 13       dodge coronet custom   8558.0   9293.744089
# 14             toyouta tercel  15750.0  19960.704320
# 15       volkswagen model 111   7995.0   5943.412451
# 16           vokswagen rabbit   7775.0   5956.315693
# ...
